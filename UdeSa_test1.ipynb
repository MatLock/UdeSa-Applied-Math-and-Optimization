# %%
import numpy as np
import matplotlib.pyplot as plt
import copy
from pylab import *

a = 1
b = 5.1/(4 * np.pi**2)
c = 5 / np.pi
r = 6
s = 10
t = 1/(8 * np.pi )

def f(x1,x2):
  return a * ((x2 - b * (x1**2) + c * x1 - r)**2) + s *(1 - t) * np.cos(x1) + s + 5 * x1

def grad(x1,x2):
  x11 = 2 * a * (x2 - b * (x1**2) + (c * x1) - r) * (-2 * b * x1 + c) - s * (1 - t) * np.sin(x1) + 5
  x12 = 2 * a * (x2 - b * (x1**2) + c * x1 - r)
  return np.array([x11,x12])


x1 = np.linspace(-5,10)
x2 = np.linspace(0,15)
X1,X2 = np.meshgrid(x1,x2, indexing = 'ij')
zz = f(X1,X2)
plt.contourf(x1,x2,zz)

# %% [markdown]
# 1.

# %%
alpha = 0.01
steps = 400

xk = np.zeros(steps+1)
yk = np.zeros(steps+1)
fk = np.zeros(steps+1)
norm = np.zeros(steps+1)

xk[0] = 6
yk[0] = 12
fk[0] = f(6,12)


for i in range(steps):
  gradient = grad(xk[i],yk[i])
  xk[i+1] = xk[i] - alpha * gradient[0]
  yk[i+1] = yk[i] - alpha * gradient[1]
  fk[i+1] = f(xk[i+1],yk[i+1])
  norm[i+1] = np.linalg.norm(gradient)

x1 = np.linspace(-5,10)
x2 = np.linspace(0,15)
X1,X2 = np.meshgrid(x1,x2, indexing = 'ij')
zz = f(X1,X2)
plt.figure(0)
plt.contourf(x1,x2,zz)
plt.plot(xk,yk,'r')
plt.figure(1)
plt.plot(fk, label="fx")
plt.plot(norm, label="norma")
plt.legend()
plt.show()

# %% [markdown]
# 2. beta = 0.8

# %%
alpha = 0.01
steps = 400
beta = 0.8

xk = np.zeros(steps+1)
yk = np.zeros(steps+1)
fk = np.zeros(steps+1)
vk_x = np.zeros(steps+1)
vk_y = np.zeros(steps+1)

norm = np.zeros(steps+1)

xk[0] = 6
yk[0] = 12
fk[0] = f(6,12)

for i in range(steps):
  gradient = grad(xk[i],yk[i])
  vk_x[i+1] = beta * vk_x[i] + alpha * gradient[0]
  vk_y[i+1] = beta * vk_y[i] + alpha * gradient[1]
  xk[i+1] = xk[i] - vk_x[i+1]
  yk[i+1] = yk[i] - vk_y[i+1]

  fk[i+1] = f(xk[i+1],yk[i+1])
  norm[i+1] = np.linalg.norm(gradient)

x1 = np.linspace(-5,10)
x2 = np.linspace(0,15)
X1,X2 = np.meshgrid(x1,x2, indexing = 'ij')
zz = f(X1,X2)
plt.figure(0)
plt.contourf(x1,x2,zz)
plt.plot(xk,yk,'r')
plt.figure(1)
plt.plot(fk, label="fx")
plt.plot(norm, label="norma")
plt.legend()
plt.show()

# %% [markdown]
# 2. beta = 0.9

# %%
alpha = 0.01
steps = 400
beta = 0.9

xk = np.zeros(steps+1)
yk = np.zeros(steps+1)
fk = np.zeros(steps+1)
vk_x = np.zeros(steps+1)
vk_y = np.zeros(steps+1)

norm =np.zeros(steps+1)

xk[0] = 6
yk[0] = 12
fk[0] = f(6,12)

for i in range(steps):
  gradient = grad(xk[i],yk[i])
  vk_x[i+1] = beta * vk_x[i] + alpha * gradient[0]
  vk_y[i+1] = beta * vk_y[i] + alpha * gradient[1]
  xk[i+1] = xk[i] - vk_x[i+1]
  yk[i+1] = yk[i] - vk_y[i+1]

  fk[i+1] = f(xk[i+1],yk[i+1])
  norm[i+1] = np.linalg.norm(gradient)

x1 = np.linspace(-5,10)
x2 = np.linspace(0,15)
X1,X2 = np.meshgrid(x1,x2, indexing = 'ij')
zz = f(X1,X2)
plt.figure(0)
plt.contourf(x1,x2,zz)
plt.plot(xk,yk,'r')
plt.figure(1)
plt.plot(fk, label="fx")
plt.plot(norm, label="norma")
plt.legend()
plt.show()

# %% [markdown]
# 3. beta =0.8

# %%
alpha = 0.01
steps = 400
beta = 0.8

xk = np.zeros(steps+1)
yk = np.zeros(steps+1)
fk = np.zeros(steps+1)
vk_x = np.zeros(steps+1)
vk_y = np.zeros(steps+1)

norm =np.zeros(steps+1)

xk[0] = 6
yk[0] = 12
fk[0] = f(6,12)

for i in range(steps):
  gradient = grad(xk[i] - beta * vk_x[i], yk[i] - beta * vk_y[i])
  vk_x[i+1] = beta * vk_x[i] + alpha * gradient[0]
  vk_y[i+1] = beta * vk_y[i] + alpha * gradient[1]
  xk[i+1] = xk[i] - vk_x[i+1]
  yk[i+1] = yk[i] - vk_y[i+1]

  fk[i+1] = f(xk[i+1],yk[i+1])
  norm[i+1] = np.linalg.norm(gradient)

x1 = np.linspace(-5,10)
x2 = np.linspace(0,15)
X1,X2 = np.meshgrid(x1,x2, indexing = 'ij')
zz = f(X1,X2)
plt.figure(0)
plt.contourf(x1,x2,zz)
plt.plot(xk,yk,'r')
plt.figure(1)
plt.plot(fk, label="fx")
plt.plot(norm, label="norma")
plt.legend()
plt.show()

# %% [markdown]
# 3. beta = 0.9

# %%
alpha = 0.01
steps = 400
beta = 0.9

xk = np.zeros(steps+1)
yk = np.zeros(steps+1)
fk = np.zeros(steps+1)
vk_x = np.zeros(steps+1)
vk_y = np.zeros(steps+1)

norm =np.zeros(steps+1)

xk[0] = 6
yk[0] = 12
fk[0] = f(6,12)

for i in range(steps):
  gradient = grad(xk[i] - beta * vk_x[i], yk[i] - beta * vk_y[i])
  vk_x[i+1] = beta * vk_x[i] + alpha * gradient[0]
  vk_y[i+1] = beta * vk_y[i] + alpha * gradient[1]
  xk[i+1] = xk[i] - vk_x[i+1]
  yk[i+1] = yk[i] - vk_y[i+1]

  fk[i+1] = f(xk[i+1],yk[i+1])
  norm[i+1] = np.linalg.norm(gradient)

x1 = np.linspace(-5,10)
x2 = np.linspace(0,15)
X1,X2 = np.meshgrid(x1,x2, indexing = 'ij')
zz = f(X1,X2)
plt.figure(0)
plt.contourf(x1,x2,zz)
plt.plot(xk,yk,'r')
plt.figure(1)
plt.plot(fk, label="fx")
plt.plot(norm, label="norma")
plt.legend()
plt.show()

# %% [markdown]
# 4.

# %%
alpha = 0.01
steps = 400
beta = 0.9
epsilon = 10**(-4)

xk = np.zeros(steps+1)
yk = np.zeros(steps+1)
fk = np.zeros(steps+1)

pkx = np.zeros(steps+1)
dkx = np.zeros(steps+1)
rkx = np.zeros(steps+1)

pky = np.zeros(steps+1)
dky = np.zeros(steps+1)
rky = np.zeros(steps+1)

norm =np.zeros(steps+1)

xk[0] = 6
yk[0] = 12
fk[0] = f(6,12)

for i in range(steps):
  gradientx = grad(xk[i], yk[i])[0]
  gradienty = grad(xk[i], yk[i])[1]

  rkx[i+1] = beta * rkx[i] + (1 - beta) * gradientx**2
  pkx[i+1] = -(np.sqrt(dkx[i] + epsilon) / np.sqrt(rkx[i+1] + epsilon) * gradientx)
  dkx[i+1] = beta * dkx[i] + (1 - beta) * (pkx[i+1]**2)

  rky[i+1] = beta * rky[i] + (1 - beta) * gradienty**2
  pky[i+1] = -(np.sqrt(dky[i] + epsilon) / np.sqrt(rky[i+1] + epsilon) * gradienty)
  dky[i+1] = beta * dky[i] + (1 - beta) * (pky[i+1]**2)

  xk[i+1] = xk[i] + pkx[i+1]
  yk[i+1] = yk[i] + pky[i+1]

  fk[i+1] = f(xk[i+1],yk[i+1])
  norm[i+1] = np.linalg.norm(gradient)

x1 = np.linspace(-5,10)
x2 = np.linspace(0,15)
X1,X2 = np.meshgrid(x1,x2, indexing = 'ij')
zz = f(X1,X2)
plt.figure(0)
plt.contourf(x1,x2,zz)
plt.plot(xk,yk,'r')
plt.figure(1)
plt.plot(fk, label="fx")
plt.plot(norm, label="norma")
plt.legend()
plt.show()

# %% [markdown]
# 1. El metodo de optimizacion 1 no posee acelerador, es simplemente un gradiente descendente con un alpha fijo (muy parecido a exact line search)
#
# 3. al cambiar los betas estas amplificando o disminuyendo el calculo de momentum para la funcion de minimizacion
# 4.mejor convergencia
